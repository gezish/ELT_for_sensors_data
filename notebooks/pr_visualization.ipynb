# %%
import pandas as pd
import sys, os

# %%
df = pd.read_csv("../data/20181024_d1_1030_1100.csv",sep="[,;:]",index_col=False)
df.head(10)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_26728\1378635900.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("../data/20181024_d1_1030_1100.csv",sep="[,;:]",index_col=False)
# C:\Users\user\AppData\Local\Temp\ipykernel_26728\1378635900.py:1: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv("../data/20181024_d1_1030_1100.csv",sep="[,;:]",index_col=False)
#    track_id             type   traveled_d   avg_speed        lat        lon  \
# 0         1              Bus        17.84   17.835195  37.977149  23.737802
# 1         2       Motorcycle        25.20   18.896364  37.977303  23.737727
# 2         3              Car        55.26   22.605440  37.977436  23.737727
# ...

# %%
df.columns
# Out:
# Index(['track_id', ' type', ' traveled_d', ' avg_speed', ' lat', ' lon',
#        ' speed', ' lon_acc', ' lat_acc', ' time'],
#       dtype='object')

# %%
df[' type'].value_counts()
# Out:
#  Car               224
#  Motorcycle        220
#  Taxi              157
#  Medium Vehicle     29
#  Bus                16
#  Heavy Vehicle       2
# Name:  type, dtype: int64

# %%
df = pd.read_csv("../data/I80_stations.csv",sep="[,;:]",index_col=False)
df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_26728\463908154.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("../data/I80_stations.csv",sep="[,;:]",index_col=False)
#        ID  Fwy Dir  District  County  City State_PM  Abs_PM   Latitude  \
# 0  402261   80   E         4      95   NaN     38.2  65.667  38.472850
# 1  402260   80   W         4      95   NaN    38.24  65.707  38.473363
# 2  402262   80   W         4      95   NaN       39  66.467  38.481149
# 3  402263   80   E         4      95   NaN       39  66.467  38.481036
# 4  402264   80   E         4      95   NaN     39.6  67.067  38.487178
#
#     Longitude  Length Type  Lanes           Name User_ID_1          User_ID_2  \
# 0 -121.823777    0.75   ML      3  4A5344 loc 66     DS953  N3-E-23-080-03820
# ...
